# %% [markdown]
# https://towardsdatascience.com/https-medium-com-tirthajyoti-build-pipelines-with-pandas-using-pdpipe-cade6128cd31?source=---------2------------------

# %% [markdown]
# https://medium.com/@shashimalsenarath.17/is-pipeline-important-in-machine-learning-pipeline-with-pdpipe-b6fc9acf20c4

# %%
# Data Analysis packages
import pandas as pd
import pandas_profiling 
import numpy as np


# Data Visualization packages
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Other useful packages
from datetime import datetime
import warnings
import os
from tqdm import tqdm, tqdm_notebook
from subprocess import check_output
from pydotplus.graphviz import graph_from_dot_data

# Sklearn API
from sklearn import datasets

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import make_pipeline

# Classification Algo Metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score, f1_score
# Regression Algo Metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

#XGBOOST
from xgboost import XGBClassifier

#Pipeline with Pandas
import pdpipe as pdp

# Stats API
import scipy.stats as stats
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
import statsmodels.formula.api as smf

plt.rc("font", size=14)
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 200)
pd.set_option('display.max_rows', 500) # OR pd.options.display.max_rows = 500
pd.set_option('display.max_columns', 500) # OR pd.options.display.max_columns = 500

# %%
df = pd.read_csv("USA_Housing.csv")

# %%
round(df.sample(5),2)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 2029          82858.45                 7.70                       8.95
# 4526          69664.08                 7.61                       5.95
# 3309          69650.59                 4.81                       8.01
# 3182          82353.29                 6.32                       6.77
# 551           75146.80                 4.45                       8.51
#
#       Avg. Area Number of Bedrooms  Area Population       Price  \
# 2029                          5.44         36835.74  2005037.31
# 4526                          2.00         37012.99  1074646.87
# 3309                          4.25         48017.37  1574582.09
# 3182                          2.49         31745.92  1459525.38
# 551                           6.10         55577.97  1560746.87
#
#                                                              Address
# 2029  9963 Terri Cove Suite 637\nPort Danielleborough, HI 98045-2788
# 4526              79506 Tony Plain Apt. 264\nMarcuschester, NC 40536
# 3309               140 Juarez Hills Suite 432\nValeriefort, SC 83268
# 3182                   610 Dale Station\nWest Williamburgh, KY 98834
# 551                 38973 Jeanette Lock\nShafferville, RI 86582-2504

# %%
df.shape
# Out:
# (5000, 7)

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
round(df.describe().T,2)
# Out:
#                                count        mean        std       min  \
# Avg. Area Income              5000.0    68583.11   10657.99  17796.63
# Avg. Area House Age           5000.0        5.98       0.99      2.64
# Avg. Area Number of Rooms     5000.0        6.99       1.01      3.24
# Avg. Area Number of Bedrooms  5000.0        3.98       1.23      2.00
# Area Population               5000.0    36163.52    9925.65    172.61
# Price                         5000.0  1232072.65  353117.63  15938.66
#
#                                     25%         50%         75%         max
# Avg. Area Income               61480.56    68804.29    75783.34   107701.75
# Avg. Area House Age                5.32        5.97        6.65        9.52
# Avg. Area Number of Rooms          6.30        7.00        7.67       10.76
# Avg. Area Number of Bedrooms       3.14        4.05        4.49        6.50
# Area Population                29403.93    36199.41    42861.29    69621.71
# Price                         997577.14  1232669.38  1471210.20  2469065.59

# %%
def size(n):
    if n<=4:
        return 'Small'
    elif 4<n<=6:
        return 'Medium'
    else:
        return 'Big'

# %%
df['House_size']=df['Avg. Area Number of Rooms'].apply(size)

# %%
round(df.sample(5),2)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 321           76192.66                 7.30                       7.34
# 2517          50847.11                 4.97                       5.36
# 2235          68596.00                 6.55                       5.91
# 4528          74452.82                 5.11                       5.46
# 1123          69044.94                 4.31                       5.60
#
#       Avg. Area Number of Bedrooms  Area Population       Price  \
# 321                           6.33         21245.84  1432756.52
# 2517                          4.38         34763.70   398909.51
# 2235                          2.09         55323.96  1388840.17
# 4528                          4.40         37298.07  1065679.12
# 1123                          4.09         34764.29  1084255.68
#
#                                                              Address  \
# 321   22588 Brian Forge Suite 588\nSouth Michelleside, NE 62469-4467
# 2517            6908 King Underpass Suite 740\nEast Thomas, MP 29298
# 2235                9569 Chloe Ports\nLake Stacyshire, NE 25955-2308
# 4528  77636 Donald Avenue Apt. 063\nLake Savannahfort, ID 71155-2535
# 1123                           937 Singh Greens\nBakerfort, HI 27291
#
#      House_size
# 321         Big
# 2517     Medium
# 2235     Medium
# 4528     Medium
# 1123     Medium

# %% [markdown]
# ### Drop a column

# %%
drop_age = pdp.ColDrop('Avg. Area House Age')

# %%
df2 = drop_age(df)

# %%
round(df2.sample(5))
# Out:
#       Avg. Area Income  Avg. Area Number of Rooms  \
# 2382           69654.0                        8.0
# 1974           60273.0                        7.0
# 2004           70587.0                        7.0
# 2629           75768.0                        8.0
# 3797           56348.0                        5.0
#
#       Avg. Area Number of Bedrooms  Area Population      Price  \
# 2382                           3.0          27023.0   717273.0
# 1974                           4.0          35890.0  1050224.0
# 2004                           4.0          31799.0   976540.0
# 2629                           3.0          27445.0  1379169.0
# 3797                           2.0          23477.0   649224.0
#
#                                                       Address House_size
# 2382      940 Kelsey Light Suite 026\nBeckstad, GU 27370-7423        Big
# 1974      8775 Angela Flats\nWest Jasonchester, CT 06251-9759        Big
# 2004          287 Fields Falls Suite 212\nWellsside, WY 48741        Big
# 2629  0627 Jonathan Spurs Apt. 121\nHarveystad, VI 29375-3726        Big
# 3797                    1629 James Pines\nPort John, LA 49420     Medium

# %% [markdown]
# ### Chaining stages by adding them up

# %%
pipeline = pdp.ColDrop('Avg. Area House Age')
pipeline+= pdp.OneHotEncode('House_size')

# %%
df3 = pipeline(df)

# %%
round(df3.sample(5))
# Out:
#       Avg. Area Income  Avg. Area Number of Rooms  \
# 2369           76908.0                        8.0
# 1412           67150.0                        8.0
# 1289           63867.0                        9.0
# 1215           76000.0                        7.0
# 4005           73428.0                        7.0
#
#       Avg. Area Number of Bedrooms  Area Population      Price  \
# 2369                           4.0          51630.0  1813856.0
# 1412                           3.0          39918.0  1376970.0
# 1289                           4.0          14523.0   917611.0
# 1215                           4.0          35184.0  1634781.0
# 4005                           6.0          42332.0  1447493.0
#
#                                                              Address  \
# 2369      765 John Falls Apt. 380\nSouth Kathrynshire, IN 61674-7121
# 1412                        16913 John Fall\nNew Lisa, NM 04867-0517
# 1289  615 Alexander Plains Suite 955\nWest Alisonberg, VA 45700-1303
# 1215         1503 Allison Freeway Apt. 398\nLake Gina, AS 58599-4858
# 4005     20495 Melissa Gardens Suite 101\nNorth Laura, CO 17542-6982
#
#       House_size_Medium  House_size_Small
# 2369                  0                 0
# 1412                  0                 0
# 1289                  0                 0
# 1215                  0                 0
# 4005                  0                 0

# %%
def price_tag(x):
    if x>250000:
        return 'keep'
    else:
        return 'drop'

# %%
pipeline = pdp.ColDrop('Avg. Area House Age')
pipeline+= pdp.OneHotEncode('House_size')
pipeline+=pdp.ApplyByCols('Price',price_tag,'Price_tag',drop=False)

# %%
df4 = pipeline(df)

# %%
df4.shape
# Out:
# (5000, 9)

# %%
round(df4.sample(5),2)
# Out:
#       Avg. Area Income  Avg. Area Number of Rooms  \
# 4182          54465.75                       6.38
# 1511          71769.86                       6.85
# 3792          65643.86                       7.10
# 2336          49435.54                       6.05
# 2850          59466.87                       7.11
#
#       Avg. Area Number of Bedrooms  Area Population       Price Price_tag  \
# 4182                          3.18          7234.96   395523.25      keep
# 1511                          4.18         28173.39  1114169.04      keep
# 3792                          6.12         48882.49  1265927.36      keep
# 2336                          3.34         43442.00   927163.81      keep
# 2850                          3.26         44825.81  1226041.78      keep
#
#                                                           Address  \
# 4182  602 Ferguson Throughway Suite 431\nNew Nathanfurt, IA 99792
# 1511   96301 Allison Falls Suite 515\nNew Courtney, GU 66573-9604
# 3792                     79881 Myers Fords\nNorth Larry, WI 13795
# 2336           289 Becky Flats Apt. 257\nWest Kara, IL 19071-5078
# 2850               61933 Sarah Landing\nFarleyview, OK 34381-6999
#
#       House_size_Medium  House_size_Small
# 4182                  0                 0
# 1511                  0                 0
# 3792                  0                 0
# 2336                  0                 0
# 2850                  0                 0

# %%
pipeline = pdp.ColDrop('Avg. Area House Age')
pipeline+= pdp.OneHotEncode('House_size')
pipeline+=pdp.ApplyByCols('Price',price_tag,'Price_tag',drop=False)
pipeline+=pdp.ValDrop(['drop'],'Price_tag')
pipeline+= pdp.ColDrop('Price_tag')

# %%
df5 = pipeline(df)

# %%
df5.shape
# Out:
# (4990, 8)

# %%
print(pipeline)
# Out:
# A pdpipe pipeline:
# [ 0]  Drop column Avg. Area House Age
# [ 1]  One-hot encode House_size
# [ 2]  Applying a function  to column Price.
# [ 3]  Drop values drop in column Price_tag
# [ 4]  Drop column Price_tag

# %% [markdown]
# ### Scikit-learn scaling

# %%
pipeline_scale = pdp.Scale('StandardScaler',exclude_columns=['House_size_Medium','House_size_Small'])
df6 = pipeline_scale(df5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-aaa03f17e101> in <module>
# ----> 1 pipeline_scale = pdp.Scale('StandardScaler',exclude_columns=['House_size_Medium','House_size_Small'])
#       2 df6 = pipeline_scale(df5)
#
# AttributeError: module 'pdpipe' has no attribute 'Scale'

# %%
df6 = pipeline_scale(df5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-9af692f64734> in <module>
# ----> 1 df6 = pipeline_scale(df5)
#
# NameError: name 'pipeline_scale' is not defined

# %%
round(df6.sample(5),3)
# Out:
#       Avg. Area Income  Avg. Area Number of Rooms  \
# 2063             2.067                     -1.195
# 1001            -0.183                      0.504
# 3801             0.044                      0.062
# 4690             1.528                     -0.738
# 3797            -1.155                     -2.088
#
#       Avg. Area Number of Bedrooms  Area Population  Price  \
# 2063                        -1.379           -0.128  1.366
# 1001                         0.840           -1.328 -1.849
# 3801                         1.164           -0.352  0.300
# 4690                         0.071            0.123  0.048
# 3797                        -1.443           -1.283 -1.671
#
#                                                 Address  House_size_Medium  \
# 2063  06374 Martin Passage\nNew Shawnland, KS 59839-...                  1
# 1001         827 Ferguson Isle\nRosebury, AL 61416-3167                  0
# 3801              Unit 8410 Box 5521\nDPO AP 20914-6877                  0
# 4690  29600 Garcia Forest Suite 239\nWest Mark, NV 5...                  0
# 3797              1629 James Pines\nPort John, LA 49420                  1
#
#       House_size_Small
# 2063                 0
# 1001                 0
# 3801                 0
# 4690                 0
# 3797                 0

# %% [markdown]
# ### NLTK stages

# %%
pipeline_tokenize=pdp.TokenizeWords('Address')
# Out:
# [nltk_data] Downloading package punkt to /Users/rajkgupta/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
df7 = pipeline_tokenize(df6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-84c9599efb4a> in <module>
# ----> 1 df7 = pipeline_tokenize(df6)
#
# NameError: name 'df6' is not defined

# %%
df7.sample(5)
# Out:
#       Avg. Area Income  Avg. Area Number of Rooms  \
# 2801         -2.163790                  -0.161473
# 646          -0.182429                  -0.023628
# 838          -0.569561                   0.185986
# 4409         -0.320249                   0.464002
# 1983         -0.004935                  -0.580628
#
#       Avg. Area Number of Bedrooms  Area Population     Price  \
# 2801                     -1.322010         0.623847 -0.359488
# 646                      -1.573084         0.104469 -0.187608
# 838                       0.314022         0.532345 -0.206402
# 4409                      0.014353        -1.373439 -0.458186
# 1983                      0.087245         0.836355 -0.598361
#
#                                                 Address  House_size_Medium  \
# 2801  [525, Ashley, Course, Lake, Michelleville, ,, ...                  0
# 646   [8961, Guerra, Motorway, Stephensburgh, ,, AR,...                  0
# 838   [86533, Gould, Hills, Garciachester, ,, DE, 09...                  0
# 4409  [089, Smith, Gateway, Suite, 155, East, Christ...                  0
# 1983       [Unit, 8667, Box, 6237, DPO, AE, 76811-0261]                  0
#
#       House_size_Small
# 2801                 0
# 646                  0
# 838                  0
# 4409                 0
# 1983                 0

# %%
def extract_state(token):
    return str(token[-2])

# %%
pipeline_state = pdp.ApplyByCols('Address',extract_state,result_columns='State')

# %%
df8=pipeline_state(df7)

# %%
round(df8.sample(5),3)
# Out:
#       Avg. Area Income  Avg. Area Number of Rooms  \
# 2150            -0.902                      0.709
# 2330             0.042                      0.092
# 3717            -1.454                      0.991
# 4187            -0.242                      0.962
# 260             -0.701                      0.098
#
#       Avg. Area Number of Bedrooms  Area Population  Price State  \
# 2150                         1.156           -1.005 -1.566    AA
# 2330                        -0.698           -0.412 -0.481    GU
# 3717                         1.011           -0.755 -1.877    CO
# 4187                         0.865           -0.975 -1.690    WV
# 260                          0.930           -0.989 -0.345    NV
#
#       House_size_Medium  House_size_Small
# 2150                  0                 0
# 2330                  0                 0
# 3717                  0                 0
# 4187                  0                 0
# 260                   0                 0
